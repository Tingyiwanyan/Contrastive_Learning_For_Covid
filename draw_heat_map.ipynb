# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
heat = pd.read_csv("24h_ce_retain_icu.csv")
heat_map = heat.pivot("Variable Name","Time Step","Positive Contribute Value")
fig = plt.figure(figsize=(5,6))
heat_ = sns.heatmap(heat_map,annot=True,cmap='BuPu')

# %%
heat
# Out:
#         Variable Name  Time Step  Positive Contribute Value
# 0    CAC-RESPIRATIONS          1              -6.080000e-07
# 1           CAC-PULSE          1               1.160000e-06
# 2          CAC-Height          1               1.580000e-17
# 3             AMYLASE          1               0.000000e+00
# 4                 PTT          1              -7.230000e-10
# 5                 AST          1              -5.270000e-12
# 6               BANDS          1               2.600000e-30
# 7          DBILIRUBIN          1               3.510000e-10
# 8          TBILIRUBIN          1               6.000000e-11
# 9                 BNP          1              -1.890000e-14
# 10                CRP          1               5.720000e-09
# 11               CKMB          1               0.000000e+00
# 12             DDIMER          1              -1.140000e-10
# 13         FIBRINOGEN          1              -1.990000e-20
# 14            GLUCOSE          1              -9.110000e-10
# 15                HCT          1               1.340000e-10
# 16                HGB          1               1.110000e-10
# 17               IRON          1               0.000000e+00
# 18                LDH          1               1.020000e-10
# 19        LYMPHO_PREC          1               2.540000e-10
# 20          MONO_PREC          1               2.110000e-10
# 21               MONO          1               3.020000e-10
# 22        NEUTRO_PREC          1               1.190000e-10
# 23             NEUTRO          1               6.020000e-12
# 24          POTASSIUM          1              -1.030000e-09
# 25                PTT          1               4.880000e-11
# 26          TROPONINI          1               3.110000e-13
# 27                WBC          1              -1.470000e-10
# 28   CAC-RESPIRATIONS          2               4.330000e-07
# 29          CAC-PULSE          2               3.760000e-07
# ..                ...        ...                        ...
# 82          TROPONINI          3               4.770000e-02
# 83                WBC          3               9.130000e-03
# 84   CAC-RESPIRATIONS          4               3.468956e-01
# 85          CAC-PULSE          4               1.652222e-01
# 86         CAC-Height          4               2.055585e-01
# 87            AMYLASE          4               2.379821e-01
# 88                PTT          4               1.950979e-01
# 89                AST          4               1.209968e-01
# 90              BANDS          4               2.520528e-01
# 91         DBILIRUBIN          4               4.432035e-01
# 92         TBILIRUBIN          4               1.669937e-01
# 93                BNP          4               1.022922e-01
# 94                CRP          4               7.723196e-01
# 95               CKMB          4               4.576816e-01
# 96             DDIMER          4               3.193758e-01
# 97         FIBRINOGEN          4               1.639697e-01
# 98            GLUCOSE          4               5.929954e-01
# 99                HCT          4               2.118677e-01
# 100               HGB          4               1.594804e-01
# 101              IRON          4               2.569496e-01
# 102               LDH          4               6.755857e-01
# 103       LYMPHO_PREC          4               1.425373e-01
# 104         MONO_PREC          4               3.664446e-01
# 105              MONO          4               4.334570e-01
# 106       NEUTRO_PREC          4               1.376673e-01
# 107            NEUTRO          4               1.879384e-01
# 108         POTASSIUM          4               1.047784e-01
# 109               PTT          4               1.694939e-01
# 110         TROPONINI          4               2.198330e+00
# 111               WBC          4               5.488587e-01
#
# [112 rows x 3 columns]
