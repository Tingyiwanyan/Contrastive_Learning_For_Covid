# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
heat = pd.read_csv("Heat_map.csv")
heat_map = heat.pivot("Variable Name","Time Step","Positive Contribute Value")
fig = plt.figure(figsize=(10,6))
heat_ = sns.heatmap(heat_map,annot=True,cmap='BuPu')

# %%
heat_map
# Out:
# Time Step           1    2      3      4
# Variable Name
# AGAP              0.0  0.0  0.320  0.000
# AST               0.0  0.0  0.726  0.000
# BASOPHIL_PRRC     0.0  0.0  0.000  1.540
# BICARB            0.0  0.0  0.395  0.000
# BICARB_A          0.0  0.0  0.273  0.421
# BUN               0.0  0.0  1.120  0.000
# CALCIUMIONIZED_A  0.0  0.0  0.089  0.178
# CREATININE        0.0  0.0  0.418  0.000
# CRP               0.0  0.0  3.190  0.000
# DIASTOLIC         0.0  0.0  0.146  0.000
# DOIMER            0.0  0.0  0.929  0.000
# EOSINO_PREC       0.0  0.0  0.000  1.730
# FIBRINOGEN        0.0  0.0  0.150  0.000
# GLUCOSE_A         0.0  0.0  0.101  0.246
# INR               0.0  0.0  0.180  0.000
# LACTATE_A         0.0  0.0  1.680  3.800
# LDH               0.0  0.0  0.139  0.000
# LYMPHO_PREC       0.0  0.0  0.000  1.761
# MONO_PREC         0.0  0.0  0.000  0.662
# PH_A              0.0  0.0  0.694  1.270
# PO2_A             0.0  0.0  0.521  0.000
# POTASSIUM_A       0.0  0.0  0.210  0.304
# PT                0.0  0.0  0.155  0.000
# PULSE             0.0  0.0  0.473  0.980
# PULSE OXIMETRY    0.0  0.0  0.632  1.150
# RESPIRATIONS      0.0  0.0  0.332  1.880
# TEMPERATURE       0.0  0.0  0.653  0.000
# TROPONINI         0.0  0.0  0.000  0.416
