# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import norm

# %%
import pandas as pd
heat = pd.read_csv("retain_cl_24h_death_full_data_heat_map.csv")
heat_map = heat.pivot("Variable Names","Time Step","Contribution Scores")
fig = plt.figure(figsize=(4,25))
heat_ = sns.heatmap(heat_map,annot=True,cmap='BuPu',cbar=False)

# %%
heat2 = pd.read_csv("retain_ce_24h_death_full_data_heat_map.csv")
heat_map2 = heat2.pivot("Variable Names","Time Step","Contribution Scores")

heat3 = pd.read_csv("retain_cl_24h_death_7_data_heat_map.csv")
heat_map3 = heat3.pivot("Variable Names","Time Step","Contribution Scores")

heat4 = pd.read_csv("retain_ce_24h_death_7_data_heat_map.csv")
heat_map4 = heat3.pivot("Variable Names","Time Step","Contribution Scores")

np.array(heat_map).shape
# Out:
# (63, 4)

# %%
norm(heat_map4)
# Out:
# 0.999572495702197

# %%
heat = pd.read_csv("retain_ce_24h_death_full_data_heat_map.csv")
heat_map = heat.pivot("Variable Names","Time Step","Contribution Scores")
fig = plt.figure(figsize=(5,25))
heat_ = sns.heatmap(np.array(heat_map),annot=True,yticklabels=False,xticklabels=[1.0,2.0,3.0,4.0],cmap='BuPu')
