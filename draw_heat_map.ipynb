# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
heat = pd.read_csv("retain_cl_24h_death_7_data_heat_map.csv")
heat_map = heat.pivot("Variable Names","Time Step","Contribution Scores")
fig = plt.figure(figsize=(5,25))
heat_ = sns.heatmap(heat_map,annot=True,cmap='BuPu')

# %%
heat = pd.read_csv("retain_ce_24h_death_7_data_heat_map.csv")
heat_map = heat.pivot("Variable Names","Time Step","Contribution Scores")
fig = plt.figure(figsize=(5,25))
heat_ = sns.heatmap(heat_map,annot=True,cmap='BuPu')
