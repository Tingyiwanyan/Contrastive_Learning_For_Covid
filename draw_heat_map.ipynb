# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
heat = pd.read_csv("full_data_mortality_24h_retain_cl_heap_map.csv")
heat_map = heat.pivot("Variable Names","Time Step","Contribution Scores")
fig = plt.figure(figsize=(5,20))
heat_ = sns.heatmap(heat_map,annot=True,cmap='BuPu')

# %%
heat
# Out:
#            Variable Names  Time Step  Contribution Scores
# 0                    high        1.0             0.025224
# 1                     low        1.0             0.041693
# 2       CAC - TEMPERATURE        1.0             0.002515
# 3    CAC - PULSE OXIMETRY        1.0             0.270298
# 4      CAC - RESPIRATIONS        1.0             0.025560
# 5             CAC - PULSE        1.0             0.087140
# 6            CAC - HEIGHT        1.0            -0.007868
# 7      CAC - WEIGHT/SCALE        1.0             0.001672
# 8                 ALBUMIN        1.0             0.170911
# 9                 ALKPHOS        1.0             0.036719
# 10                    ALT        1.0             0.383578
# 11                   AGAP        1.0             0.351226
# 12                    PTT        1.0             0.080909
# 13                    AST        1.0             2.558521
# 14              ATYPLYMPH        1.0             0.021623
# 15                  BANDS        1.0             0.093371
# 16             DBILIRUBIN        1.0             0.094326
# 17             TBILIRUBIN        1.0             0.103916
# 18                    BNP        1.0            -0.104260
# 19                    BUN        1.0             1.241112
# 20                    CRP        1.0             0.361528
# 21         CALCIUMIONIZED        1.0             0.007098
# 22                CALCIUM        1.0             0.073456
# 23               CHLORIDE        1.0             0.002410
# 24                    CPK        1.0             0.423673
# 25                   CKMB        1.0            -0.047730
# 26                 BICARB        1.0             0.041997
# 27             CREATININE        1.0             0.607408
# 28                 DDIMER        1.0             0.470181
# 29               FERRITIN        1.0             0.180767
# ..                    ...        ...                  ...
# 222                   HGB        4.0            -0.000269
# 223                   INR        4.0             0.077983
# 224                   IL6        4.0             0.076901
# 225                  IRON        4.0             0.000000
# 226               LACTATE        4.0             2.176904
# 227                   LDH        4.0             5.707344
# 228           LYMPHO_PERC        4.0             0.180785
# 229                LYMPHO        4.0             0.042399
# 230                  MCHC        4.0             0.000074
# 231                   MCV        4.0            -0.013586
# 232                   MPV        4.0             0.045419
# 233             MONO_PERC        4.0             0.216441
# 234                  MONO        4.0             0.020259
# 235           NEUTRO_PERC        4.0             0.032414
# 236                NEUTRO        4.0             0.458817
# 237                 O2SAT        4.0             0.116151
# 238                  PCO2        4.0             0.282212
# 239                    PH        4.0             0.029984
# 240                   PLT        4.0             0.063691
# 241                   PO2        4.0             0.015860
# 242             POTASSIUM        4.0             0.299349
# 243                    PT        4.0             0.032854
# 244               PROTEIN        4.0             0.012417
# 245                RBCCNT        4.0             0.005424
# 246                   RDW        4.0            -0.008809
# 247                SODIUM        4.0             0.012564
# 248                  TIBC        4.0             0.000000
# 249        TRANSFERRINSAT        4.0             0.000000
# 250             TROPONINI        4.0            -0.012713
# 251                   WBC        4.0             1.018225
#
# [252 rows x 3 columns]
