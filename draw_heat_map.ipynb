# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
heat = pd.read_csv("24h_retain_ce_intubation.csv")
heat_map = heat.pivot("Variable Name","Time Step","Positive Contribute Value")
fig = plt.figure(figsize=(5,6))
heat_ = sns.heatmap(heat_map,annot=True,cmap='BuPu')

# %%
heat_map
# Out:
# Time Step              1       2         3         4
# Variable Name
# AGAP            0.164624  0.1600  0.298421  0.354554
# BASOPHIL        0.344191  0.6630  0.415634  0.421602
# BASOPHIL_PREC   0.704274  0.5990  0.694628  0.928923
# BUN             0.596818  0.7400  1.062949  0.988938
# CKMB            0.312419  0.2030  0.351856  0.426264
# CREATININE      0.291885  0.3920  0.632173  0.330608
# CRP             0.268985  0.0694  0.236558  0.871859
# DDIMER          0.119313  0.7100  0.556965  0.208530
# DIASTOLIC       0.098514  0.0735  0.156109  0.424889
# EOSINO          0.114170  0.2810  0.184990  0.255044
# EOSINO_PREC     0.848960  0.8150  0.901005  1.317914
# FERRITIN       -0.047345  0.0000  0.356352  1.151104
# GLUCOSE         0.155140  0.1500  0.167219  0.358249
# IL6             0.000000  0.0000  0.009787  1.530421
# LACTATE         0.052520  0.1450  0.074350  0.420099
# LDH             0.253125  0.0926  0.332565  0.268602
# ...
